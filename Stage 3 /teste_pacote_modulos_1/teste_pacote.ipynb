# %%
#montando o drive

from google.colab import drive
drive.mount('/content/Drive')
print('Drive montado com sucesso!')
# Out:
# Mounted at /content/Drive
# Drive montado com sucesso!

# %%
import sys
import os

# Defina o caminho para a pasta que contém seu pacote 'meu_pacote_modulos_1' no Google Drive.
# Certifique-se de que este caminho está correto!
DIRETORIO_PAI_PACOTE = '/content/Drive/MyDrive/ColabNotebooks/Pacotes'

# Adiciona o diretório pai do pacote ao sys.path
if DIRETORIO_PAI_PACOTE not in sys.path:
    sys.path.append(DIRETORIO_PAI_PACOTE)
    print(f"'{DIRETORIO_PAI_PACOTE}' adicionado ao sys.path")
else:
    print(f"'{DIRETORIO_PAI_PACOTE}' já está no sys.path")

# Opcional: Verificar o sys.path para confirmar
# print(sys.path)
# Out:
# '/content/Drive/MyDrive/ColabNotebooks/Pacotes' adicionado ao sys.path

# %%
# Agora você pode importar os módulos ou funções do seu pacote
# Importar o módulo completo:
import meu_pacote_modulos_1.matematica
import meu_pacote_modulos_1.strings
import meu_pacote_modulos_1.arquivos

# Ou importar funções específicas de um módulo:
from meu_pacote_modulos_1.matematica import somar, subtrair

print("Módulos e/ou funções importados com sucesso!")
# Out:
# Módulos e/ou funções importados com sucesso!

# %%
# Exemplos de uso das funções importadas:

# Usando funções importadas diretamente (somar, subtrair)
resultado_soma = somar(11, 6)
print(f"Resultado da soma: {resultado_soma}")

resultado_subtracao = subtrair(17, 7)
print(f"Resultado da subtração: {resultado_subtracao}")

# Usando funções através do nome do módulo (multiplicar, reverter_string)
resultado_multiplicacao = meu_pacote_modulos_1.matematica.multiplicar(4, 6)
print(f"Resultado da multiplicação: {resultado_multiplicacao}")

string_original = "Olá Colab"
string_invertida = meu_pacote_modulos_1.strings.reverter_string(string_original)
print(f"String original: {string_original}, String invertida: {string_invertida}")

# Exemplo de uso do módulo arquivos (crie um arquivo de teste primeiro se necessário)
# Para testar a leitura e escrita, você precisaria criar um arquivo no seu Drive primeiro
# Por exemplo, crie um arquivo 'teste.txt' na mesma pasta do seu pacote

# caminho_arquivo_teste = f'{DIRETORIO_PAI_PACOTE}/meu_pacote_modulos_1/teste.txt'
# meu_pacote_modulos_1.arquivos.escrever_arquivo(caminho_arquivo_teste, "Este é um teste.")
# conteudo_lido = meu_pacote_modulos_1.arquivos.ler_arquivo(caminho_arquivo_teste)
# print(f"Conteúdo lido do arquivo: {conteudo_lido}")
# Out:
# Resultado da soma: 17
# Resultado da subtração: 10
# Resultado da multiplicação: 24
# String original: Olá Colab, String invertida: baloC álO

# %%
# Out:
# /bin/bash: -c: line 1: unexpected EOF while looking for matching `"'
# /bin/bash: -c: line 2: syntax error: unexpected end of file
